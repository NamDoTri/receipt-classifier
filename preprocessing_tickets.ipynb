# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
flight_1_df = pd.read_csv("datasets/ARCHIVED/flight tickets/flights_tickets_serp2018-12-16.csv")
flight_1_df = flight_1_df[['searchTerms', 'title', 'snippet', 'htmlSnippet', 'htmlTitle']] # only show the needed columns
flight_1_df
# Out:
#                searchTerms                                              title  \
# 0     flights to hong kong  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1     flights to hong kong  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2     flights to hong kong  Cheap Flights to Hong Kong International from ...
# 3     flights to hong kong  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4     flights to hong kong  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
# ...                    ...                                                ...
# 3995       tickets to nice                    Billetterie Officielle OGC Nice
# 3996       tickets to nice  OGC Nice Tickets | Buy or Sell Tickets for OGC...
# 3997       tickets to nice  5 Cheap Flights to Nice, France (NCE) @ £137 2...
# 3998       tickets to nice  Nice Ville to Milan by Train from €14.90 | Tim...
# 3999       tickets to nice  Flights to Nice (NCE) | KLM Nice tickets from ...
#
# ...

# %%
# Out:
#                searchTerms                                              title  \
# 0     flights to hong kong  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1     flights to hong kong  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2     flights to hong kong  Cheap Flights to Hong Kong International from ...
# 3     flights to hong kong  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4     flights to hong kong  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
# ...                    ...                                                ...
# 3995       tickets to nice                    Billetterie Officielle OGC Nice
# 3996       tickets to nice  OGC Nice Tickets | Buy or Sell Tickets for OGC...
# 3997       tickets to nice  5 Cheap Flights to Nice, France (NCE) @ £137 2...
# 3998       tickets to nice  Nice Ville to Milan by Train from €14.90 | Tim...
# 3999       tickets to nice  Flights to Nice (NCE) | KLM Nice tickets from ...
#
# ...
